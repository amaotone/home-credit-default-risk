# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../output/v14_cv_pred.csv')

# %%
df.p.hist(bins=50)
dplt.show()

# %%
train = pd.read_feather('../input/application_train.ftr')

# %%
pos = df[df.TARGET==1]
neg = df[df.TARGET==0]

# %%
neg.p.hist(bins=50)
pos.p.hist(bins=50)

# %%
train.iloc[df.query("TARGET==1 and p<0.03").index, :]
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 624         100714       1         Cash loans           F            N
# 782         100896       1         Cash loans           F            N
# 1137        101330       1    Revolving loans           M            Y
# 1312        101541       1         Cash loans           F            N
# 1507        101772       1         Cash loans           F            N
# 1644        101929       1    Revolving loans           F            Y
# 1699        101988       1         Cash loans           F            N
# 2181        102559       1         Cash loans           F            N
# 2197        102578       1         Cash loans           F            N
# 2404        102809       1         Cash loans           F            N
# 2898        103380       1         Cash loans           F            N
# 2902        103384       1         Cash loans           F            N
# ...

# %%
from sklearn.metrics import roc_curve

# %%
fpr, tpr, thresh = roc_curve(y_true=df.TARGET, y_score=df.p)

# %%
fig, ax = plt.subplots(ncols=1, nrows=1)
ax.plot(fpr, tpr)
ax.set_aspect('equal')
plt.show()
