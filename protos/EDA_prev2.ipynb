# %% [markdown]
# # prev features

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', 0)

import missingno as msno

from tqdm import tqdm
tqdm.pandas()

# %%
train = pd.read_feather('../input/application_train.ftr')
test = pd.read_feather('../input/application_test.ftr')
buro = pd.read_feather('../input/bureau.ftr')
buro_bal = pd.read_feather('../input/bureau_balance.ftr')
prev = pd.read_feather('../input/previous_application.ftr')
inst = pd.read_feather('../input/installments_payments.ftr')
credit = pd.read_feather('../input/credit_card_balance.ftr')
pos = pd.read_feather('../input/POS_CASH_balance.ftr')

# %% [markdown]
# ## PREVIOUS

# %%
prev = pd.read_feather('../input/previous_application.ftr')
prev.replace({'XNA': np.nan, 'XAP': np.nan}, inplace=True)
prev.loc[:, prev.columns.str.startswith('DAYS_')] = prev.filter(regex='^DAYS_').replace({365243: np.nan})
prev = prev.sort_values(['SK_ID_CURR', 'DAYS_DECISION']).reset_index(drop=True)

# %% [markdown]
# ### previous / missing

# %%
prev_sample = prev.sample(1000)
msno.matrix(prev_sample, figsize=(15, 3))
plt.show()
msno.bar(prev_sample, figsize=(15, 3))
plt.show()

# %%
X = pd.pivot_table(prev, index=['SELLERPLACE_AREA'], values=['SK_ID_PREV'], columns=['NAME_CONTRACT_STATUS'], aggfunc='count', fill_value=0)

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda = LatentDirichletAllocation(n_components=5, learning_method='batch')

# %%
lda.fit(X)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=5, n_jobs=1, n_topics=None, perp_tol=0.1,
#              random_state=None, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
X.columns.names[1]
# Out:
# 'NAME_CONTRACT_STATUS'

# %%
lda.transform(X)
# Out:
# array([[6.81045041e-02, 1.78229942e-02, 3.67274897e-01, 2.11672978e-01,
#         3.35124627e-01],
#        [1.81442378e-01, 2.38626685e-01, 1.46166946e-01, 2.84185435e-01,
#         1.49578556e-01],
#        [3.37104659e-01, 6.47619716e-01, 3.90202253e-05, 1.51975851e-02,
#         3.90202412e-05],
#        ...,
#        [2.02668617e-02, 9.18936464e-01, 2.02356318e-02, 2.03223636e-02,
#         2.02386787e-02],
#        [1.01794059e-01, 5.92828542e-01, 1.01571975e-01, 1.02212132e-01,
#         1.01593293e-01],
#        [3.37913830e-02, 8.64840186e-01, 3.37375198e-02, 3.38881469e-02,
#         3.37427646e-02]])

# %%
prev
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY            ...              DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  NFLAG_INSURED_ON_APPROVAL
# 0           1369693      100001     Consumer loans     3951.000            ...                                -1499.0        -1619.0           -1612.0                        0.0
# 1           1038818      100002     Consumer loans     9251.775            ...                                  125.0          -25.0             -17.0                        0.0
# 2           2396755      100003     Consumer loans     6737.310            ...                                -1980.0        -1980.0           -1976.0                        1.0
# 3           2636178      100003     Consumer loans    64567.665            ...                                 -647.0         -647.0            -639.0                        0.0
# 4           1810518      100003         Cash loans    98356.995            ...                                 -386.0         -536.0            -527.0                        1.0
# 5           1564014      100004     Consumer loans     5357.250            ...                                 -694.0         -724.0            -714.0                        0.0
# 6           2495675      100005     Consumer loans     4813.200            ...                                 -376.0         -466.0            -460.0                        0.0
# 7           1857999      100005         Cash loans          NaN            ...                                    NaN            NaN               NaN                        NaN
# 8           2299329      100006     Consumer loans     2482.920            ...                                 -215.0         -425.0            -416.0                        0.0
# 9           1020698      100006         Cash loans    39954.510            ...                                    NaN            NaN               NaN                        NaN
# 10          2190416      100006     Consumer loans    29027.520            ...                                   49.0            NaN               NaN                        0.0
# 11          2078043      100006         Cash loans    24246.000            ...                                 1259.0         -151.0            -143.0                        0.0
# 12          2827850      100006    Revolving loans          NaN            ...                                    NaN            NaN               NaN                        NaN
# 13          1489396      100006    Revolving loans    13500.000            ...                                    NaN            NaN               NaN                        0.0
# 14          1243599      100006         Cash loans          NaN            ...                                    NaN            NaN               NaN                        NaN
# 15          2545789      100006         Cash loans          NaN            ...                                    NaN            NaN               NaN                        NaN
# 16          1697039      100006         Cash loans    32696.100            ...                                    NaN            NaN               NaN                        NaN
# 17          2119973      100007     Consumer loans     1834.290            ...                                -2056.0        -2056.0           -2041.0                        1.0
# 18          2462742      100007     Consumer loans     3601.530            ...                                -1406.0        -1406.0           -1397.0                        0.0
# 19          1940724      100007         Cash loans    22678.785            ...                                 -746.0         -746.0            -739.0                        1.0
# 20          2730157      100007         Cash loans    13010.985            ...                                    NaN            NaN               NaN                        NaN
# 21          2001242      100007         Cash loans    16509.600            ...                                 -324.0         -354.0            -347.0                        0.0
# 22          1692033      100007         Cash loans    16037.640            ...                                  346.0            NaN               NaN                        1.0
# 23          1186888      100008     Consumer loans     8019.090            ...                                -2341.0        -2341.0           -2334.0                        0.0
# 24          1907290      100008     Consumer loans    12144.285            ...                                -2029.0        -2029.0            -703.0                        0.0
# 25          2613879      100008         Cash loans    25309.575            ...                                  261.0         -399.0            -388.0                        1.0
# 26          2218188      100008     Consumer loans    17885.835            ...                                  -69.0          -69.0             -66.0                        0.0
# 27          1757431      100008         Cash loans          NaN            ...                                    NaN            NaN               NaN                        NaN
# 28          1112703      100009     Consumer loans     9845.010            ...                                -1261.0        -1261.0           -1252.0                        0.0
# 29          1193310      100009     Consumer loans    17341.605            ...                                -1330.0        -1330.0           -1323.0                        0.0
# ...             ...         ...                ...          ...            ...                                    ...            ...               ...                        ...
# 1670184     2390857      456247     Consumer loans          NaN            ...                                    NaN            NaN               NaN                        NaN
# 1670185     1522534      456247     Consumer loans    17304.480            ...                                 -329.0         -329.0            -321.0                        0.0
# 1670186     1395578      456248     Consumer loans     8417.340            ...                                -2499.0        -2499.0           -2495.0                        1.0
# 1670187     1826280      456248         Cash loans    28633.320            ...                                 -762.0         -762.0            -759.0                        1.0
# 1670188     1136073      456248         Cash loans    67725.495            ...                                  -20.0          -20.0             -17.0                        1.0
# 1670189     2743495      456248    Revolving loans    45000.000            ...                                    NaN            NaN               NaN                        0.0
# 1670190     2660508      456249         Cash loans    22770.405            ...                                -1165.0        -1165.0           -1156.0                        0.0
# 1670191     2669123      456249     Consumer loans    11497.500            ...                                    NaN            NaN               NaN                        NaN
# 1670192     1922117      456250     Consumer loans    26084.430            ...                                 -888.0         -888.0            -884.0                        0.0
# 1670193     1740566      456250         Cash loans    26474.625            ...                                 -377.0         -377.0            -374.0                        1.0
# 1670194     1511244      456250         Cash loans          NaN            ...                                    NaN            NaN               NaN                        NaN
# 1670195     2626069      456250         Cash loans    19151.100            ...                                    NaN            NaN               NaN                        NaN
# 1670196     1794451      456250    Revolving loans     9000.000            ...                                    NaN            NaN               NaN                        0.0
# 1670197     1482581      456250    Revolving loans          NaN            ...                                    NaN            NaN               NaN                        NaN
# 1670198     2624169      456250         Cash loans          NaN            ...                                    NaN            NaN               NaN                        NaN
# 1670199     1081068      456250     Consumer loans     7847.685            ...                                   54.0            NaN               NaN                        0.0
# 1670200     2248017      456251     Consumer loans     6605.910            ...                                    0.0          -30.0             -25.0                        0.0
# 1670201     1503599      456252     Consumer loans    10074.465            ...                                -2316.0        -2316.0           -2311.0                        1.0
# 1670202     1668235      456253     Consumer loans     3973.095            ...                                -2722.0        -2722.0           -2713.0                        1.0
# 1670203     1686207      456253     Consumer loans     5567.715            ...                                -1716.0        -1716.0           -1712.0                        0.0
# 1670204     1792910      456254     Consumer loans     2296.440            ...                                   99.0            NaN               NaN                        0.0
# 1670205     2016407      456254     Consumer loans    19065.825            ...                                  203.0            NaN               NaN                        1.0
# 1670206     1743609      456255     Consumer loans    11090.835            ...                                 -630.0         -690.0            -687.0                        0.0
# 1670207     2631384      456255         Cash loans    54022.140            ...                                  294.0          -66.0             -64.0                        0.0
# 1670208     1179690      456255         Cash loans    28873.170            ...                                   28.0         -212.0            -204.0                        1.0
# 1670209     2073384      456255         Cash loans    16400.610            ...                                   72.0         -558.0            -528.0                        1.0
# 1670210     2729207      456255     Consumer loans    11514.555            ...                                 -319.0         -409.0            -400.0                        0.0
# 1670211     1359084      456255     Consumer loans    11314.170            ...                                  -95.0         -215.0            -211.0                        0.0
# 1670212     1708056      456255    Revolving loans     2250.000            ...                                    NaN            NaN               NaN                        NaN
# 1670213     1296007      456255         Cash loans    30737.655            ...                                    NaN            NaN               NaN                        NaN
#
# [1670214 rows x 37 columns]

# %%
prev.loc[:, prev.isnull().sum() == 0]
# Out:
#          SK_ID_PREV  SK_ID_CURR  AMT_APPLICATION WEEKDAY_APPR_PROCESS_START       ...         NAME_CONTRACT_STATUS DAYS_DECISION             CHANNEL_TYPE SELLERPLACE_AREA
# 0           1369693      100001         24835.50                     FRIDAY       ...                     Approved         -1740             Country-wide               23
# 1           1038818      100002        179055.00                   SATURDAY       ...                     Approved          -606                    Stone              500
# 2           2396755      100003         68809.50                   SATURDAY       ...                     Approved         -2341             Country-wide              200
# 3           2636178      100003        337500.00                     SUNDAY       ...                     Approved          -828                    Stone             1400
# 4           1810518      100003        900000.00                     FRIDAY       ...                     Approved          -746  Credit and cash offices               -1
# 5           1564014      100004         24282.00                     FRIDAY       ...                     Approved          -815         Regional / Local               30
# 6           2495675      100005         44617.50                   THURSDAY       ...                     Approved          -757             Country-wide               37
# 7           1857999      100005             0.00                     FRIDAY       ...                     Canceled          -315  Credit and cash offices               -1
# 8           2299329      100006         26912.34                    TUESDAY       ...                     Approved          -617                    Stone               30
# 9           1020698      100006        454500.00                   SATURDAY       ...                     Approved          -438  Credit and cash offices               -1
# 10          2190416      100006        334917.00                     SUNDAY       ...                     Approved          -311             Country-wide             8025
# 11          2078043      100006        675000.00                   THURSDAY       ...                     Approved          -181  Credit and cash offices               -1
# 12          2827850      100006             0.00                   THURSDAY       ...                     Canceled          -181  Credit and cash offices               -1
# 13          1489396      100006        270000.00                   THURSDAY       ...                     Approved          -181  Credit and cash offices               -1
# 14          1243599      100006             0.00                   THURSDAY       ...                     Canceled          -181  Credit and cash offices               -1
# 15          2545789      100006             0.00                   THURSDAY       ...                     Canceled          -181  Credit and cash offices               -1
# 16          1697039      100006        688500.00                   THURSDAY       ...                      Refused          -181  Credit and cash offices               -1
# 17          2119973      100007         17176.50                   SATURDAY       ...                     Approved         -2357             Country-wide             1200
# 18          2462742      100007         31005.00                     SUNDAY       ...                     Approved         -1768             Country-wide               53
# 19          1940724      100007        202500.00                   THURSDAY       ...                     Approved         -1106             Country-wide               -1
# 20          2730157      100007        225000.00                     FRIDAY       ...                     Approved          -867          AP+ (Cash loan)                4
# 21          2001242      100007        180000.00                     SUNDAY       ...                     Approved          -865         Regional / Local             1200
# 22          1692033      100007        247500.00                     MONDAY       ...                     Approved          -374  Credit and cash offices               -1
# 23          1186888      100008         44455.50                     MONDAY       ...                     Approved         -2536             Country-wide               50
# 24          1907290      100008        121455.00                     MONDAY       ...                     Approved         -2333         Regional / Local               96
# 25          2613879      100008        450000.00                     MONDAY       ...                     Approved          -639             Country-wide              110
# 26          2218188      100008        162598.50                   THURSDAY       ...                     Approved          -370             Country-wide              110
# 27          1757431      100008             0.00                     FRIDAY       ...                     Canceled           -82  Credit and cash offices               -1
# 28          1112703      100009         98460.00                   SATURDAY       ...                     Approved         -1562         Regional / Local              190
# 29          1193310      100009        110160.00                     MONDAY       ...                     Approved         -1511         Regional / Local              190
# ...             ...         ...              ...                        ...       ...                          ...           ...                      ...              ...
# 1670184     2390857      456247         52510.50                     SUNDAY       ...                      Refused          -650             Country-wide               45
# 1670185     1522534      456247         65295.00                  WEDNESDAY       ...                     Approved          -451                    Stone               30
# 1670186     1395578      456248         39960.00                   THURSDAY       ...                     Approved         -2680             Country-wide               30
# 1670187     1826280      456248        225000.00                     MONDAY       ...                     Approved         -1122  Credit and cash offices               -1
# 1670188     1136073      456248       1260000.00                     FRIDAY       ...                     Approved          -740  Credit and cash offices               -1
# 1670189     2743495      456248             0.00                     FRIDAY       ...                     Approved          -740  Credit and cash offices               -1
# 1670190     2660508      456249        180000.00                     MONDAY       ...                     Approved         -1526  Credit and cash offices               -1
# 1670191     2669123      456249        114210.00                  WEDNESDAY       ...                      Refused         -1454                    Stone               69
# 1670192     1922117      456250        141570.00                     FRIDAY       ...                     Approved         -1069                    Stone               38
# 1670193     1740566      456250        225000.00                     MONDAY       ...                     Approved          -737  Credit and cash offices               -1
# 1670194     1511244      456250             0.00                   THURSDAY       ...                     Canceled          -454  Credit and cash offices               -1
# 1670195     2626069      456250        450000.00                   THURSDAY       ...                      Refused          -454  Credit and cash offices               -1
# 1670196     1794451      456250        180000.00                     MONDAY       ...                     Approved          -373  Credit and cash offices               -1
# 1670197     1482581      456250             0.00                     MONDAY       ...                     Canceled          -373  Credit and cash offices               -1
# 1670198     2624169      456250             0.00                     MONDAY       ...                     Canceled          -373           Contact center               -1
# 1670199     1081068      456250         66091.50                     FRIDAY       ...                     Approved          -327             Country-wide               36
# 1670200     2248017      456251         40455.00                   THURSDAY       ...                     Approved          -273             Country-wide               30
# 1670201     1503599      456252         57595.50                  WEDNESDAY       ...                     Approved         -2497             Country-wide              190
# 1670202     1668235      456253         19413.00                    TUESDAY       ...                     Approved         -2851                    Stone               22
# 1670203     1686207      456253         28912.50                   SATURDAY       ...                     Approved         -1909                    Stone               22
# 1670204     1792910      456254         18846.00                  WEDNESDAY       ...                     Approved          -322             Country-wide               63
# 1670205     2016407      456254        223789.50                   SATURDAY       ...                     Approved          -277             Country-wide             3093
# 1670206     1743609      456255        102037.50                   THURSDAY       ...                     Approved          -991         Regional / Local              500
# 1670207     2631384      456255       1170000.00                     FRIDAY       ...                     Approved          -787          AP+ (Cash loan)                6
# 1670208     1179690      456255        450000.00                    TUESDAY       ...                     Approved          -692  Credit and cash offices               -1
# 1670209     2073384      456255        229500.00                   THURSDAY       ...                     Approved          -648  Credit and cash offices               -1
# 1670210     2729207      456255         58225.50                     FRIDAY       ...                     Approved          -500             Country-wide               20
# 1670211     1359084      456255         82404.00                     SUNDAY       ...                     Approved          -456             Country-wide               50
# 1670212     1708056      456255         45000.00                     SUNDAY       ...                      Refused          -456             Country-wide               20
# 1670213     1296007      456255        765000.00                     FRIDAY       ...                      Refused          -171  Credit and cash offices               -1
#
# [1670214 rows x 11 columns]

# %%
prev.groupby('SK_ID_CURR').SK_ID_PREV.count().hist(bins=100)
plt.show()

# %%
prev.DAYS_DECISION.hist(bins=100)

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
prev.groupby('SK_ID_CURR').SELLERPLACE_AREA.value_counts()
# Out:
# SK_ID_CURR  SELLERPLACE_AREA
# 100001       23                  1
# 100002       500                 1
# 100003      -1                   1
#              200                 1
#              1400                1
# 100004       30                  1
# 100005      -1                   1
#              37                  1
# 100006      -1                   7
#              30                  1
#              8025                1
# 100007      -1                   2
#              1200                2
#              4                   1
#              53                  1
# 100008       110                 2
#             -1                   1
#              50                  1
#              96                  1
# 100009       164                 3
#              190                 2
#              18                  1
#              300                 1
# 100010       8636                1
# 100011      -1                   2
#              0                   1
#              1371                1
# 100012      -1                   3
#              42                  1
# 100013      -1                   2
#                                 ..
# 456243       150                 5
#              90                  1
#              200                 1
# 456244      -1                  13
#              0                   4
#              1000                1
# 456245       4                   1
#              21                  1
# 456246       9                   1
#              30                  1
# 456247       30                  2
#              45                  2
#              40                  1
# 456248      -1                   3
#              30                  1
# 456249      -1                   1
#              69                  1
# 456250      -1                   6
#              36                  1
#              38                  1
# 456251       30                  1
# 456252       190                 1
# 456253       22                  2
# 456254       63                  1
#              3093                1
# 456255      -1                   3
#              20                  2
#              6                   1
#              50                  1
#              500                 1
# Name: SELLERPLACE_AREA, Length: 852844, dtype: int64

# %%
prev.groupby('SK_ID_CURR').SELLERPLACE_AREA.apply(lambda x: x.value_counts().index[0])
# Out:
# SK_ID_CURR
# 100001      23
# 100002     500
# 100003    1400
# 100004      30
# 100005      37
# 100006      -1
# 100007      -1
# 100008     110
# 100009     164
# 100010    8636
# 100011      -1
# 100012      -1
# 100013      -1
# 100014      30
# 100015     110
# 100016     200
# 100017    2500
# 100018    1200
# 100019    1000
# 100020     550
# 100021     200
# 100022      -1
# 100023       4
# 100025      -1
# 100026      -1
# 100027       5
# 100028    3500
# 100029      18
# 100030      30
# 100032     246
#           ...
# 456225      -1
# 456226      -1
# 456227      -1
# 456228      -1
# 456230    2566
# 456231      -1
# 456232     150
# 456233     150
# 456234      25
# 456235     200
# 456236      -1
# 456237      -1
# 456238     100
# 456239      40
# 456240      -1
# 456241      -1
# 456242     500
# 456243     150
# 456244      -1
# 456245      21
# 456246      30
# 456247      30
# 456248      -1
# 456249      69
# 456250      -1
# 456251      30
# 456252     190
# 456253      22
# 456254      63
# 456255      -1
# Name: SELLERPLACE_AREA, Length: 338857, dtype: int64

# %%
prev.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION            ...              DAYS_FIRST_DUE  DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE DAYS_TERMINATION  NFLAG_INSURED_ON_APPROVAL
# 0     1369693      100001     Consumer loans     3951.000          24835.5            ...                     -1709.0                    -1499.0        -1619.0          -1612.0                        0.0
# 1     1038818      100002     Consumer loans     9251.775         179055.0            ...                      -565.0                      125.0          -25.0            -17.0                        0.0
# 2     2396755      100003     Consumer loans     6737.310          68809.5            ...                     -2310.0                    -1980.0        -1980.0          -1976.0                        1.0
# 3     2636178      100003     Consumer loans    64567.665         337500.0            ...                      -797.0                     -647.0         -647.0           -639.0                        0.0
# 4     1810518      100003         Cash loans    98356.995         900000.0            ...                      -716.0                     -386.0         -536.0           -527.0                        1.0
#
# [5 rows x 37 columns]

# %%
inst
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  AMT_INSTALMENT  AMT_PAYMENT
# 0            1054186      161674                     1.0                      6          -1180.0             -1187.0        6948.360     6948.360
# 1            1330831      151639                     0.0                     34          -2156.0             -2156.0        1716.525     1716.525
# 2            2085231      193053                     2.0                      1            -63.0               -63.0       25425.000    25425.000
# 3            2452527      199697                     1.0                      3          -2418.0             -2426.0       24350.130    24350.130
# 4            2714724      167756                     1.0                      2          -1383.0             -1366.0        2165.040     2160.585
# 5            1137312      164489                     1.0                     12          -1384.0             -1417.0        5970.375     5970.375
# 6            2234264      184693                     4.0                     11           -349.0              -352.0       29432.295    29432.295
# 7            1818599      111420                     2.0                      4           -968.0              -994.0       17862.165    17862.165
# 8            2723183      112102                     0.0                     14           -197.0              -197.0          70.740       70.740
# 9            1413990      109741                     1.0                      4           -570.0              -609.0       14308.470    14308.470
# 10           1782554      106597                     1.0                      3           -933.0              -937.0       34620.525    34620.525
# 11           2558880      154793                     1.0                      8          -1262.0             -1269.0       15031.080    15031.080
# 12           1570206      147645                     0.0                     20           -761.0              -761.0          21.510       21.510
# 13           1723268      197273                     1.0                     14           -755.0              -800.0        6093.990     6093.990
# 14           1594684      100193                     0.0                     56          -1153.0             -1153.0         301.860      301.860
# 15           1456258      118323                     1.0                      6          -2619.0             -2619.0        4844.925     4844.925
# 16           1053286      170192                     1.0                      7           -500.0              -503.0        6882.840     6882.840
# 17           1410565      197687                     1.0                      1          -1037.0             -1048.0       12514.050    12510.450
# 18           2391610      183431                     0.0                     20          -1680.0             -1693.0        7875.000     7875.000
# 19           2329072      183463                     1.0                     11          -1699.0             -1693.0        7283.295     7283.295
# 20           1354314      196570                     1.0                     14           -361.0              -365.0       15219.000    15219.000
# 21           2260765      106012                     3.0                     23            -56.0               -59.0       13494.915    13494.915
# 22           1995642      134723                     1.0                     38          -1277.0             -1282.0       12949.200    12949.200
# 23           2631836      140337                     0.0                    116           -322.0              -322.0         560.880      560.880
# 24           2702769      102122                     1.0                      1           -281.0              -286.0        5178.195     5178.195
# 25           1770345      128334                     1.0                      5           -240.0              -255.0       10649.925    10649.925
# 26           1818333      191655                     1.0                      6           -345.0              -356.0       16479.270    16479.270
# 27           1991673      162903                     0.0                     46          -2548.0             -2561.0        5400.000     5400.000
# 28           1184783      140804                     0.0                    106           -155.0              -155.0         503.460      503.460
# 29           1181315      174565                     1.0                      7          -1894.0             -1895.0       16274.790    16274.790
# ...              ...         ...                     ...                    ...              ...                 ...             ...          ...
# 13605371     1860833      415656                     2.0                      1           -180.0                 NaN      344249.955          NaN
# 13605372     1860833      415656                     1.0                      1           -180.0                 NaN       24127.200          NaN
# 13605373     1829584      450349                     1.0                     18            -10.0                 NaN       18730.350          NaN
# 13605374     1659443      405841                     0.0                    101          -1919.0                 NaN          67.500          NaN
# 13605375     2497183      419772                     0.0                     39          -1877.0                 NaN          67.500          NaN
# 13605376     1421163      453693                     0.0                     60          -1387.0                 NaN          67.500          NaN
# 13605377     2596933      419968                     1.0                     15            -42.0                 NaN       51394.680          NaN
# 13605378     2181137      409380                     0.0                    108           -422.0                 NaN         130.500          NaN
# 13605379     1062206      409297                     0.0                     44          -1955.0                 NaN          67.500          NaN
# 13605380     1421163      453693                     0.0                     59          -1417.0                 NaN          67.500          NaN
# 13605381     1263000      406628                     0.0                     45           -808.0                 NaN          67.500          NaN
# 13605382     2263477      443619                     1.0                      9            -61.0                 NaN        5152.095          NaN
# 13605383     1499195      418486                     6.0                     22           -412.0                 NaN       48635.595          NaN
# 13605384     2454112      400586                     0.0                     27          -1720.0                 NaN          67.500          NaN
# 13605385     2239217      451572                     0.0                     76           -131.0                 NaN          46.980          NaN
# 13605386     1847946      405063                     0.0                     40          -2057.0                 NaN           0.090          NaN
# 13605387     2630714      441748                     1.0                      4            -36.0                 NaN       14707.125          NaN
# 13605388     2831819      417123                     0.0                      8            -15.0                 NaN        4399.740          NaN
# 13605389     2186857      428057                     0.0                     69          -1532.0                 NaN          67.500          NaN
# 13605390     1829584      450349                     1.0                     16            -70.0                 NaN       18730.350          NaN
# 13605391     1499195      418486                     6.0                     32           -112.0                 NaN       48635.595          NaN
# 13605392     2448869      434321                     1.0                     16           -117.0                 NaN       11504.250          NaN
# 13605393     1285736      434069                     0.0                     73           -853.0                 NaN          67.500          NaN
# 13605394     1659443      405841                     0.0                    102          -1888.0                 NaN          67.500          NaN
# 13605395     1499195      418486                     6.0                      2          -1012.0                 NaN       48635.595          NaN
# 13605396     2186857      428057                     0.0                     66          -1624.0                 NaN          67.500          NaN
# 13605397     1310347      414406                     0.0                     47          -1539.0                 NaN          67.500          NaN
# 13605398     1308766      402199                     0.0                     43             -7.0                 NaN       43737.435          NaN
# 13605399     1062206      409297                     0.0                     43          -1986.0                 NaN          67.500          NaN
# 13605400     2448869      434321                     1.0                     19            -27.0                 NaN       11504.250          NaN
#
# [13605401 rows x 8 columns]

# %%
prev.merge(inst, on='SK_ID_PREV', how='left')
# Out:
#           SK_ID_PREV  SK_ID_CURR_x NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION     ...       NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT AMT_INSTALMENT  AMT_PAYMENT
# 0            1369693        100001     Consumer loans     3951.000          24835.5     ...                         1.0          -1709.0             -1715.0       3951.000     3951.000
# 1            1369693        100001     Consumer loans     3951.000          24835.5     ...                         2.0          -1679.0             -1715.0       3951.000     3951.000
# 2            1369693        100001     Consumer loans     3951.000          24835.5     ...                         4.0          -1619.0             -1628.0      17397.900    17397.900
# 3            1369693        100001     Consumer loans     3951.000          24835.5     ...                         3.0          -1649.0             -1660.0       3951.000     3951.000
# 4            1038818        100002     Consumer loans     9251.775         179055.0     ...                        16.0           -115.0              -133.0       9251.775     9251.775
# 5            1038818        100002     Consumer loans     9251.775         179055.0     ...                         8.0           -355.0              -375.0       9251.775     9251.775
# 6            1038818        100002     Consumer loans     9251.775         179055.0     ...                        19.0            -25.0               -49.0      53093.745    53093.745
# 7            1038818        100002     Consumer loans     9251.775         179055.0     ...                        12.0           -235.0              -250.0       9251.775     9251.775
# 8            1038818        100002     Consumer loans     9251.775         179055.0     ...                         9.0           -325.0              -344.0       9251.775     9251.775
# 9            1038818        100002     Consumer loans     9251.775         179055.0     ...                        13.0           -205.0              -224.0       9251.775     9251.775
# 10           1038818        100002     Consumer loans     9251.775         179055.0     ...                        14.0           -175.0              -194.0       9251.775     9251.775
# 11           1038818        100002     Consumer loans     9251.775         179055.0     ...                        17.0            -85.0               -99.0       9251.775     9251.775
# 12           1038818        100002     Consumer loans     9251.775         179055.0     ...                        18.0            -55.0               -67.0       9251.775     9251.775
# 13           1038818        100002     Consumer loans     9251.775         179055.0     ...                         3.0           -505.0              -529.0       9251.775     9251.775
# 14           1038818        100002     Consumer loans     9251.775         179055.0     ...                        15.0           -145.0              -160.0       9251.775     9251.775
# 15           1038818        100002     Consumer loans     9251.775         179055.0     ...                         6.0           -415.0              -446.0       9251.775     9251.775
# 16           1038818        100002     Consumer loans     9251.775         179055.0     ...                         1.0           -565.0              -587.0       9251.775     9251.775
# 17           1038818        100002     Consumer loans     9251.775         179055.0     ...                         2.0           -535.0              -562.0       9251.775     9251.775
# 18           1038818        100002     Consumer loans     9251.775         179055.0     ...                        10.0           -295.0              -312.0       9251.775     9251.775
# 19           1038818        100002     Consumer loans     9251.775         179055.0     ...                        11.0           -265.0              -284.0       9251.775     9251.775
# 20           1038818        100002     Consumer loans     9251.775         179055.0     ...                         5.0           -445.0              -468.0       9251.775     9251.775
# 21           1038818        100002     Consumer loans     9251.775         179055.0     ...                         4.0           -475.0              -498.0       9251.775     9251.775
# 22           1038818        100002     Consumer loans     9251.775         179055.0     ...                         7.0           -385.0              -412.0       9251.775     9251.775
# 23           2396755        100003     Consumer loans     6737.310          68809.5     ...                         4.0          -2220.0             -2226.0       6737.310     6737.310
# 24           2396755        100003     Consumer loans     6737.310          68809.5     ...                         9.0          -2070.0             -2071.0       6737.310     6737.310
# 25           2396755        100003     Consumer loans     6737.310          68809.5     ...                         5.0          -2190.0             -2199.0       6737.310     6737.310
# 26           2396755        100003     Consumer loans     6737.310          68809.5     ...                         7.0          -2130.0             -2136.0       6737.310     6737.310
# 27           2396755        100003     Consumer loans     6737.310          68809.5     ...                        12.0          -1980.0             -1985.0       6662.970     6662.970
# 28           2396755        100003     Consumer loans     6737.310          68809.5     ...                        10.0          -2040.0             -2044.0       6737.310     6737.310
# 29           2396755        100003     Consumer loans     6737.310          68809.5     ...                        11.0          -2010.0             -2013.0       6737.310     6737.310
# ...              ...           ...                ...          ...              ...     ...                         ...              ...                 ...            ...          ...
# 13065854     1179690        456255         Cash loans    28873.170         450000.0     ...                        10.0           -392.0              -397.0      28873.170    28873.170
# 13065855     1179690        456255         Cash loans    28873.170         450000.0     ...                        14.0           -272.0              -268.0      28873.170    27184.050
# 13065856     1179690        456255         Cash loans    28873.170         450000.0     ...                        14.0           -272.0              -266.0      28873.170     1689.120
# 13065857     1179690        456255         Cash loans    28873.170         450000.0     ...                         2.0           -632.0              -648.0      28873.170    28873.170
# 13065858     1179690        456255         Cash loans    28873.170         450000.0     ...                        13.0           -302.0              -301.0      28873.170    28873.170
# 13065859     1179690        456255         Cash loans    28873.170         450000.0     ...                         1.0           -662.0              -692.0      28873.170    28873.170
# 13065860     1179690        456255         Cash loans    28873.170         450000.0     ...                         9.0           -422.0              -435.0      28873.170    28873.170
# 13065861     1179690        456255         Cash loans    28873.170         450000.0     ...                        15.0           -242.0              -237.0      28873.170    28641.150
# 13065862     1179690        456255         Cash loans    28873.170         450000.0     ...                        16.0           -212.0              -221.0     231387.525   231387.525
# 13065863     1179690        456255         Cash loans    28873.170         450000.0     ...                         8.0           -452.0              -455.0      28873.170    28873.170
# 13065864     1179690        456255         Cash loans    28873.170         450000.0     ...                        11.0           -362.0              -366.0      28873.170    28873.170
# 13065865     2073384        456255         Cash loans    16400.610         229500.0     ...                         3.0           -558.0              -573.0     249830.685   249830.685
# 13065866     2073384        456255         Cash loans    16400.610         229500.0     ...                         1.0           -618.0              -648.0      16400.610       34.965
# 13065867     2073384        456255         Cash loans    16400.610         229500.0     ...                         2.0           -588.0              -586.0      16400.610    16319.115
# 13065868     2073384        456255         Cash loans    16400.610         229500.0     ...                         2.0           -588.0              -613.0      16400.610       81.495
# 13065869     2073384        456255         Cash loans    16400.610         229500.0     ...                         1.0           -618.0              -613.0      16400.610    16365.645
# 13065870     2729207        456255     Consumer loans    11514.555          58225.5     ...                         3.0           -409.0              -435.0      42754.230    42754.230
# 13065871     2729207        456255     Consumer loans    11514.555          58225.5     ...                         1.0           -469.0              -482.0      11514.555    11514.555
# 13065872     2729207        456255     Consumer loans    11514.555          58225.5     ...                         2.0           -439.0              -455.0      11514.555    11514.555
# 13065873     1359084        456255     Consumer loans    11314.170          82404.0     ...                         8.0           -215.0              -237.0      49984.380    49984.380
# 13065874     1359084        456255     Consumer loans    11314.170          82404.0     ...                         4.0           -335.0              -339.0      11314.170    11314.170
# 13065875     1359084        456255     Consumer loans    11314.170          82404.0     ...                         6.0           -275.0              -273.0      11314.170     9248.220
# 13065876     1359084        456255     Consumer loans    11314.170          82404.0     ...                         2.0           -395.0              -404.0      11314.170    11314.170
# 13065877     1359084        456255     Consumer loans    11314.170          82404.0     ...                         5.0           -305.0              -308.0      11314.170    11314.170
# 13065878     1359084        456255     Consumer loans    11314.170          82404.0     ...                         6.0           -275.0              -268.0      11314.170     2065.950
# 13065879     1359084        456255     Consumer loans    11314.170          82404.0     ...                         3.0           -365.0              -366.0      11314.170    11314.170
# 13065880     1359084        456255     Consumer loans    11314.170          82404.0     ...                         1.0           -425.0              -435.0      11314.170    11314.170
# 13065881     1359084        456255     Consumer loans    11314.170          82404.0     ...                         7.0           -245.0              -243.0      11314.170    11314.170
# 13065882     1708056        456255    Revolving loans     2250.000          45000.0     ...                         NaN              NaN                 NaN            NaN          NaN
# 13065883     1296007        456255         Cash loans    30737.655         765000.0     ...                         NaN              NaN                 NaN            NaN          NaN
#
# [13065884 rows x 44 columns]

# %%
pos = pos.sort_values(['SK_ID_CURR', 'MONTHS_BALANCE']).reset_index(drop=True)

# %%
pos.groupby('SK_ID_CURR').tail(1).NAME_CONTRACT_STATUS.value_counts()
# Out:
# Completed                188746
# Active                   147403
# Signed                      810
# Returned to the store       180
# Demand                       67
# Approved                     33
# Amortized debt               13
# Name: NAME_CONTRACT_STATUS, dtype: int64

# %%
pos[pos.SK_ID_CURR==100001].sort_values(['SK_ID_PREV', 'MONTHS_BALANCE']).groupby('SKO_ID_CURR').apply(lambda x:)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 7167007     1369693      100001             -57             4.0
# 8789081     1369693      100001             -56             4.0
# 7823681     1369693      100001             -55             4.0
# 4704415     1369693      100001             -54             4.0
# 2197888     1369693      100001             -53             4.0
# 1261679     1851984      100001             -96             4.0
# 1891462     1851984      100001             -95             4.0
# 8531326     1851984      100001             -94             4.0
# 4928574     1851984      100001             -93             4.0
#
#          CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 7167007                    4.0               Active       0           0
# 8789081                    3.0               Active       0           0
# 7823681                    2.0               Active       0           0
# 4704415                    1.0               Active       0           0
# 2197888                    0.0            Completed       0           0
# 1261679                    2.0               Active       0           0
# 1891462                    1.0               Active       7           7
# 8531326                    0.0               Active       0           0
# 4928574                    0.0            Completed       0           0

# %%
credit = credit.sort_values(['SK_ID_CURR', 'MONTHS_BALANCE']).reset_index(drop=True)
credit.head(30)
# Out:
#     SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  AMT_CREDIT_LIMIT_ACTUAL     ...      CNT_DRAWINGS_POS_CURRENT  CNT_INSTALMENT_MATURE_CUM  NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0      1489396      100006              -6        0.000                   270000     ...                           NaN                        0.0                Active       0           0
# 1      1489396      100006              -5        0.000                   270000     ...                           NaN                        0.0                Active       0           0
# 2      1489396      100006              -4        0.000                   270000     ...                           NaN                        0.0                Active       0           0
# 3      1489396      100006              -3        0.000                   270000     ...                           NaN                        0.0                Active       0           0
# 4      1489396      100006              -2        0.000                   270000     ...                           NaN                        0.0                Active       0           0
# 5      1489396      100006              -1        0.000                   270000     ...                           NaN                        0.0                Active       0           0
# 6      1843384      100011             -75   189000.000                   180000     ...                           0.0                        NaN                Active       0           0
# 7      1843384      100011             -74   184568.850                   180000     ...                           0.0                        1.0                Active       0           0
# 8      1843384      100011             -73   181044.540                   180000     ...                           0.0                        2.0                Active       0           0
# 9      1843384      100011             -72   177544.350                   180000     ...                           0.0                        3.0                Active       0           0
# 10     1843384      100011             -71   173901.915                   180000     ...                           0.0                        4.0                Active       0           0
# 11     1843384      100011             -70   170289.720                   180000     ...                           0.0                        5.0                Active       0           0
# 12     1843384      100011             -69   166628.160                   180000     ...                           0.0                        6.0                Active       0           0
# 13     1843384      100011             -68   162659.970                   180000     ...                           0.0                        7.0                Active       0           0
# 14     1843384      100011             -67   158878.845                   180000     ...                           0.0                        8.0                Active       0           0
# 15     1843384      100011             -66   154960.740                   180000     ...                           0.0                        9.0                Active       0           0
# 16     1843384      100011             -65   151067.115                   180000     ...                           0.0                       10.0                Active       0           0
# 17     1843384      100011             -64   147030.300                   180000     ...                           0.0                       11.0                Active       0           0
# 18     1843384      100011             -63   143069.310                   180000     ...                           0.0                       12.0                Active       0           0
# 19     1843384      100011             -62   139041.540                   180000     ...                           0.0                       13.0                Active       0           0
# 20     1843384      100011             -61   134885.970                   180000     ...                           0.0                       14.0                Active       0           0
# 21     1843384      100011             -60   130734.630                   180000     ...                           0.0                       15.0                Active       0           0
# 22     1843384      100011             -59   126455.040                   180000     ...                           0.0                       16.0                Active       0           0
# 23     1843384      100011             -58   122180.265                   180000     ...                           0.0                       17.0                Active       0           0
# 24     1843384      100011             -57   117834.255                   180000     ...                           0.0                       18.0                Active       0           0
# 25     1843384      100011             -56   113242.365                   180000     ...                           0.0                       19.0                Active       0           0
# 26     1843384      100011             -55   108744.615                   180000     ...                           0.0                       20.0                Active       0           0
# 27     1843384      100011             -54   104130.630                   180000     ...                           0.0                       21.0                Active       0           0
# 28     1843384      100011             -53    99493.290                   180000     ...                           0.0                       22.0                Active       0           0
# 29     1843384      100011             -52    94741.560                   180000     ...                           0.0                       23.0                Active       0           0
#
# [30 rows x 23 columns]

# %%
inst = inst.sort_values(['SK_ID_CURR', 'DAYS_INSTALMENT']).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e7769b3e64ac> in <module>()
# ----> 1 inst = inst.sort_values(['SK_ID_CURR', 'DAYS_INSTALMENT']).reset_index(drop=True)
#
# NameError: name 'inst' is not defined

# %%
df = pd.read_feather('../working/prev_train.ftr')

# %%
df.isnull().sum()
# Out:
# prev_AMT_ANNUITY                               16871
# prev_AMT_APPLICATION                           16454
# prev_AMT_CREDIT                                16454
# prev_AMT_DOWN_PAYMENT                          33906
# prev_AMT_GOODS_PRICE                           17429
# prev_HOUR_APPR_PROCESS_START                   16454
# prev_NFLAG_LAST_APPL_IN_DAY                    16454
# prev_RATE_DOWN_PAYMENT                         33906
# prev_RATE_INTEREST_PRIMARY                    302902
# prev_RATE_INTEREST_PRIVILEGED                 302902
# prev_DAYS_DECISION                             16454
# prev_SELLERPLACE_AREA                          16454
# prev_CNT_PAYMENT                               16869
# prev_DAYS_FIRST_DRAWING                       254159
# prev_DAYS_FIRST_DUE                            18281
# prev_DAYS_LAST_DUE_1ST_VERSION                 20492
# prev_DAYS_LAST_DUE                             38399
# prev_DAYS_TERMINATION                          40497
# prev_NFLAG_INSURED_ON_APPROVAL                 17751
# prev_is_approved                               16454
# prev_null_cnt                                  16454
# prev_count                                     16454
# prev_sellerplace_mode                          16454
# prev_lda_NAME_CONTRACT_TYPE_0_mean             16454
# prev_lda_NAME_CONTRACT_TYPE_1_mean             16454
# prev_lda_NAME_CONTRACT_TYPE_2_mean             16454
# prev_lda_NAME_CONTRACT_TYPE_3_mean             16454
# prev_lda_NAME_CONTRACT_TYPE_4_mean             16454
# prev_lda_WEEKDAY_APPR_PROCESS_START_0_mean     16454
# prev_lda_WEEKDAY_APPR_PROCESS_START_1_mean     16454
#                                                ...
# prev_lda_NAME_PORTFOLIO_0_mode                 16454
# prev_lda_NAME_PORTFOLIO_1_mode                 16454
# prev_lda_NAME_PORTFOLIO_2_mode                 16454
# prev_lda_NAME_PORTFOLIO_3_mode                 16454
# prev_lda_NAME_PORTFOLIO_4_mode                 16454
# prev_lda_NAME_PRODUCT_TYPE_0_mode              19395
# prev_lda_NAME_PRODUCT_TYPE_1_mode              19395
# prev_lda_NAME_PRODUCT_TYPE_2_mode              19395
# prev_lda_NAME_PRODUCT_TYPE_3_mode              19395
# prev_lda_NAME_PRODUCT_TYPE_4_mode              19395
# prev_lda_CHANNEL_TYPE_0_mode                   16454
# prev_lda_CHANNEL_TYPE_1_mode                   16454
# prev_lda_CHANNEL_TYPE_2_mode                   16454
# prev_lda_CHANNEL_TYPE_3_mode                   16454
# prev_lda_CHANNEL_TYPE_4_mode                   16454
# prev_lda_NAME_SELLER_INDUSTRY_0_mode           16457
# prev_lda_NAME_SELLER_INDUSTRY_1_mode           16457
# prev_lda_NAME_SELLER_INDUSTRY_2_mode           16457
# prev_lda_NAME_SELLER_INDUSTRY_3_mode           16457
# prev_lda_NAME_SELLER_INDUSTRY_4_mode           16457
# prev_lda_NAME_YIELD_GROUP_0_mode               16455
# prev_lda_NAME_YIELD_GROUP_1_mode               16455
# prev_lda_NAME_YIELD_GROUP_2_mode               16455
# prev_lda_NAME_YIELD_GROUP_3_mode               16455
# prev_lda_NAME_YIELD_GROUP_4_mode               16455
# prev_lda_PRODUCT_COMBINATION_0_mode            16454
# prev_lda_PRODUCT_COMBINATION_1_mode            16454
# prev_lda_PRODUCT_COMBINATION_2_mode            16454
# prev_lda_PRODUCT_COMBINATION_3_mode            16454
# prev_lda_PRODUCT_COMBINATION_4_mode            16454
# Length: 183, dtype: int64

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
inst_sample = inst.g
plt.scatter(inst.AMT_INSTALMENT, inst.AMT_PAYMENT)
# Out:
# ERROR:tornado.general:Uncaught exception, closing connection.
# Traceback (most recent call last):
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2737, in run_cell
#     self.events.trigger('post_execute')
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/events.py", line 73, in trigger
#     func(*args, **kwargs)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 113, in flush_figures
#     return show(True)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 36, in show
#     display(figure_manager.canvas.figure)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/display.py", line 297, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/formatters.py", line 180, in format
#     data = formatter(obj)
#   File "<decorator-gen-9>", line 2, in __call__
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/formatters.py", line 224, in catch_format_error
#     r = method(self, *args, **kwargs)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/formatters.py", line 341, in __call__
#     return printer(obj)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 238, in <lambda>
#     png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 122, in print_figure
#     fig.canvas.print_figure(bytes_io, **kw)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/backend_bases.py", line 2218, in print_figure
#     bbox = a.get_window_extent(renderer)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/collections.py", line 208, in get_window_extent
#     return self.get_datalim(transforms.IdentityTransform())
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/collections.py", line 199, in get_datalim
#     offsets, transOffset.frozen())
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/path.py", line 1015, in get_path_collection_extents
#     offsets, offset_transform))
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/path.py", line 266, in should_simplify
#     @property
# KeyboardInterrupt
# ERROR:tornado.general:Uncaught exception, closing connection.
# Traceback (most recent call last):
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2737, in run_cell
#     self.events.trigger('post_execute')
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/events.py", line 73, in trigger
#     func(*args, **kwargs)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 113, in flush_figures
#     return show(True)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 36, in show
#     display(figure_manager.canvas.figure)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/display.py", line 297, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/formatters.py", line 180, in format
#     data = formatter(obj)
#   File "<decorator-gen-9>", line 2, in __call__
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/formatters.py", line 224, in catch_format_error
#     r = method(self, *args, **kwargs)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/formatters.py", line 341, in __call__
#     return printer(obj)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 238, in <lambda>
#     png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 122, in print_figure
#     fig.canvas.print_figure(bytes_io, **kw)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/backend_bases.py", line 2218, in print_figure
#     bbox = a.get_window_extent(renderer)
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/collections.py", line 208, in get_window_extent
#     return self.get_datalim(transforms.IdentityTransform())
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/collections.py", line 199, in get_datalim
#     offsets, transOffset.frozen())
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/path.py", line 1015, in get_path_collection_extents
#     offsets, offset_transform))
#   File "/Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/path.py", line 266, in should_simplify
#     @property
# KeyboardInterrupt

# %%
sns.pairplot(inst[['AMT_INSTALMENT', 'AMT_PAYMENT']])
# Out:
# /Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /Users/amane/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-e888a48ea5e8> in <module>()
# ----> 1 sns.pairplot(inst[['AMT_INSTALMENT', 'AMT_PAYMENT']])
#
# ~/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2058     if grid.square_grid:
#    2059         if diag_kind == "hist":
# -> 2060             grid.map_diag(plt.hist, **diag_kws)
#    2061         elif diag_kind == "kde":
#    2062             diag_kws["legend"] = False
#
# ~/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1363                     func(vals, color=color, **kwargs)
#    1364                 else:
# -> 1365                     func(vals, color=color, histtype="barstacked", **kwargs)
#    1366
#    1367             else:
#
# ~/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3002                       histtype=histtype, align=align, orientation=orientation,
#    3003                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3004                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3005     finally:
#    3006         ax._hold = washold
#
# ~/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ~/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6205             # this will automatically overwrite bins,
#    6206             # so that each histogram uses the same bins
# -> 6207             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6208             m = m.astype(float)  # causes problems later if it's an int
#    6209             if mlast is None:
#
# ~/.pyenv/versions/3.6.1/envs/compe/lib/python3.6/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     665     if first_edge > last_edge:
#     666         raise ValueError(
# --> 667             'max must be larger than min in range parameter.')
#     668     if not np.all(np.isfinite([first_edge, last_edge])):
#     669         raise ValueError(
#
# ValueError: max must be larger than min in range parameter.
