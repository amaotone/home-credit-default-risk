# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 0)

from tqdm import tqdm
tqdm.pandas()

from pathlib import Path

import seaborn as sns
sns.set_style('darkgrid')

import os
print(os.listdir('../data/input/'))
# Out:
# ['bureau_balance.csv.zip', 'application_train.csv.zip', 'application_test.ftr', 'credit_card_balance.csv.zip', 'application_test.csv.zip', 'credit_card_balance.ftr', 'installments_payments.ftr', 'application_train.ftr', 'POS_CASH_balance.ftr', 'installments_payments.csv.zip', 'POS_CASH_balance.csv.zip', 'bureau.ftr', 'sample_submission.ftr', 'bureau_balance.ftr', 'previous_application.ftr', 'bureau.csv.zip', 'previous_application.csv.zip', 'sample_submission.csv.zip']

# %%
for f in Path('../data/input').glob('*.ftr'):
    print(f.stem)
    locals()[f.stem] = pd.read_feather(f)
# Out:
# application_test
# credit_card_balance
# installments_payments
# application_train
# POS_CASH_balance
# bureau
# sample_submission
# bureau_balance
# previous_application

# %% [markdown]
# ## train + test

# %%
application_train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER             ...             AMT_REQ_CREDIT_BUREAU_WEEK AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100002       1         Cash loans           M             ...                                    0.0                       0.0                        0.0                         1.0
# 1      100003       0         Cash loans           F             ...                                    0.0                       0.0                        0.0                         0.0
# 2      100004       0    Revolving loans           M             ...                                    0.0                       0.0                        0.0                         0.0
# 3      100006       0         Cash loans           F             ...                                    NaN                       NaN                        NaN                         NaN
# ...

# %%
def plot_hist(col, func=None, **kwargs):
    kwargs['bins'] = kwargs.get('bins', 50)
    kwargs['alpha'] = kwargs.get('alpha', .9)
    fig, axes = plt.subplots(figsize=(12, 3), ncols=2)
    trn = application_train[col].dropna()
    tst = application_test[col].dropna()
    if func:
        axes[0].hist(func(trn[application_train.TARGET==0]), label='0', **kwargs)
        axes[0].hist(func(trn[application_train.TARGET==1]), label='1', **kwargs)
        axes[1].hist(func(trn), label='train', **kwargs)
        axes[1].hist(func(tst), label='test', **kwargs)
    else:
        axes[0].hist(trn[application_train.TARGET==0], label='0', **kwargs)
        axes[0].hist(trn[application_train.TARGET==1], label='1', **kwargs)
        axes[1].hist(trn, label='train', **kwargs)
        axes[1].hist(tst, label='test', **kwargs)
    axes[0].set_ylabel(col)
    axes[0].legend()
    axes[1].legend()
    plt.show()

# %%
for col in application_train.columns[application_train.columns.str.startswith('AMT_')]:
    plot_hist(col, np.log1p)

# %%
plot_hist('AMT_INCOME_TOTAL', np.log1p)
plot_hist('AMT_CREDIT', np.log1p)
plot_hist('AMT_ANNUITY', np.log1p)
plot_hist('AMT_GOODS_PRICE', np.log1p)

# %% [markdown]
# ## previous_application

# %%
previous_application.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION            ...              DAYS_FIRST_DUE  DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE DAYS_TERMINATION  NFLAG_INSURED_ON_APPROVAL
# 0     2030495      271877     Consumer loans     1730.430          17145.0            ...                       -42.0                      300.0          -42.0            -37.0                        0.0
# 1     2802425      108129         Cash loans    25188.615         607500.0            ...                      -134.0                      916.0       365243.0         365243.0                        1.0
# 2     2523466      122040         Cash loans    15060.735         112500.0            ...                      -271.0                       59.0       365243.0         365243.0                        1.0
# ...

# %%
previous_application.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION            ...              DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  NFLAG_INSURED_ON_APPROVAL
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06            ...                          997149.000000  997149.000000     997149.000000              997149.000000
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05            ...                           33767.774054   76582.403064      81992.343838                   0.332570
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05            ...                          106857.034789  149647.415123     153303.516729                   0.471134
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00            ...                           -2801.000000   -2889.000000      -2874.000000                   0.000000
# ...

# %%
previous_application

# %%
application_train
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002       1         Cash loans           M            N
# 1           100003       0         Cash loans           F            N
# 2           100004       0    Revolving loans           M            Y
# 3           100006       0         Cash loans           F            N
# 4           100007       0         Cash loans           M            N
# 5           100008       0         Cash loans           M            N
# 6           100009       0         Cash loans           F            Y
# 7           100010       0         Cash loans           M            Y
# 8           100011       0         Cash loans           F            N
# 9           100012       0    Revolving loans           M            N
# 10          100014       0         Cash loans           F            N
# 11          100015       0         Cash loans           F            N
# ...
